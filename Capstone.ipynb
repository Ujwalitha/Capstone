# %% [markdown]
# <a href="https://colab.research.google.com/github/Ujwalitha/Capstone/blob/master/Capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
df = pd.read_excel('/content/drive/My Drive/Forest Covertype Data Set.xlsx')

# %%
df.head()
# Out:
#    Elevation  Aspect  Slope  ...  Soil_Type39  Soil_Type40  Cover_Type
# 0       2596      51      3  ...            0            0           5
# 1       2590      56      2  ...            0            0           5
# 2       2804     139      9  ...            0            0           2
# 3       2785     155     18  ...            0            0           2
# 4       2595      45      2  ...            0            0           5
#
# [5 rows x 55 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581012 entries, 0 to 581011
# Data columns (total 55 columns):
# Elevation                             581012 non-null int64
# Aspect                                581012 non-null int64
# Slope                                 581012 non-null int64
# Horizontal_Distance_To_Hydrology      581012 non-null int64
# Vertical_Distance_To_Hydrology        581012 non-null int64
# Horizontal_Distance_To_Roadways       581012 non-null int64
# Hillshade_9am                         581012 non-null int64
# Hillshade_Noon                        581012 non-null int64
# Hillshade_3pm                         581012 non-null int64
# Horizontal_Distance_To_Fire_Points    581012 non-null int64
# Wilderness_Area1                      581012 non-null int64
# Wilderness_Area2                      581012 non-null int64
# Wilderness_Area3                      581012 non-null int64
# Wilderness_Area4                      581012 non-null int64
# ...

# %%
df.columns
# Out:
# Index(['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
#        'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
#        'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
#        'Horizontal_Distance_To_Fire_Points', 'Wilderness_Area1',
#        'Wilderness_Area2', 'Wilderness_Area3', 'Wilderness_Area4',
#        'Soil_Type1', 'Soil_Type2', 'Soil_Type3', 'Soil_Type4', 'Soil_Type5',
#        'Soil_Type6', 'Soil_Type7', 'Soil_Type8', 'Soil_Type9', 'Soil_Type10',
#        'Soil_Type11', 'Soil_Type12', 'Soil_Type13', 'Soil_Type14',
#        'Soil_Type15', 'Soil_Type16', 'Soil_Type17', 'Soil_Type18',
#        'Soil_Type19', 'Soil_Type20', 'Soil_Type21', 'Soil_Type22',
#        'Soil_Type23', 'Soil_Type24', 'Soil_Type25', 'Soil_Type26',
#        'Soil_Type27', 'Soil_Type28', 'Soil_Type29', 'Soil_Type30',
#        'Soil_Type31', 'Soil_Type32', 'Soil_Type33', 'Soil_Type34',
#        'Soil_Type35', 'Soil_Type36', 'Soil_Type37', 'Soil_Type38',
# ...

# %%
cols = ['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
       'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
       'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
       'Horizontal_Distance_To_Fire_Points']
fig=plt.subplots(figsize=(10,15))
for i, j in enumerate(cols):
    plt.subplot(5, 2, i+1)
    plt.subplots_adjust(hspace = 1.0)
    sns.distplot(df[j])
    plt.xticks(rotation=90)
    plt.title("Forest Cover Type")
    
plt.show()

# %%
cols = ['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
       'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
       'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
       'Horizontal_Distance_To_Fire_Points']
fig=plt.subplots(figsize=(10,15))
for i, j in enumerate(cols):
    plt.subplot(5, 2, i+1)
    plt.subplots_adjust(hspace = 1.0)
    sns.boxplot(df[j])
    plt.xticks(rotation=90)
    plt.title("Forest Cover Type")
    
plt.show()

# %%
sns.distplot(df['Elevation'])

# %%
### Treating campaign Outliers with IQR method
for col in cols :
  q1,q2,q3 = df[col].quantile([0.25,0.50,0.75])
  iqr = q3-q1
  upper = q3 + (1.5*iqr)
  lower = q1 - (1.5*iqr)
  print('Upper and Lower values for camapign is',upper,lower)
  print(col, (df.shape[0]-df[(df[col]<=upper) & (df[col]>=lower)].shape[0])/df.shape[0]*100)
# Out:
# Upper and Lower values for camapign is 3694.0 2278.0
# Elevation 2.67963484403076
# Upper and Lower values for camapign is 563.0 -245.0
# Aspect 0.0
# Upper and Lower values for camapign is 31.5 -4.5
# Slope 2.6360901323896924
# Upper and Lower values for camapign is 798.0 -306.0
# Horizontal_Distance_To_Hydrology 2.5054559974664894
# Upper and Lower values for camapign is 162.0 -86.0
# Vertical_Distance_To_Hydrology 5.4152065706043935
# Upper and Lower values for camapign is 6661.0 -2227.0
# Horizontal_Distance_To_Roadways 0.1151439212959457
# Upper and Lower values for camapign is 280.5 148.5
# Hillshade_9am 3.000454379599733
# Upper and Lower values for camapign is 273.0 177.0
# Hillshade_Noon 2.6973625329597324
# Upper and Lower values for camapign is 241.5 45.5
# Hillshade_3pm 1.3479928125408769
# Upper and Lower values for camapign is 4839.0 -1265.0
# Horizontal_Distance_To_Fire_Points 5.362539844271719

# %% [markdown]
# Almost 7-8% of the data would be lost if we remove the extreme values. Instead we can go with one of the transformation techniques.

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['Cover_Type'])

# %%
df['Cover_Type'].value_counts()
# Out:
# 2    283301
# 1    211840
# 3     35754
# 7     20510
# 6     17367
# 5      9493
# 4      2747
# Name: Cover_Type, dtype: int64

# %%
sns.boxplot(df['Elevation'])

# %%
 from scipy import stats
sns.distplot(stats.boxcox(df['Elevation'])[0])

# %%
sns.boxplot(stats.boxcox(df['Elevation'])[0])

# %%
pd.Series(stats.boxcox(df['Elevation'])[0]).skew()
# Out:
# -0.03637851015539085

# %%
df['Elevation'].skew()
# Out:
# -0.8175958182693059

# %% [markdown]
# After applying boxcox transformation to the column 'Elevation', the skewness decreased from 0.8 to 0.03

# %%
sns.distplot(df['Slope'])

# %%
sns.distplot(np.sqrt(df['Slope']))

# %%
sns.boxplot(np.sqrt(df['Slope']))

# %%
np.sqrt(df['Slope']).skew()
# Out:
# 0.024458689346826587

# %%
df['Slope'].skew()
# Out:
# 0.7892725471932496

# %% [markdown]
# After applying square root transformation to the column 'Slope', the skewness decreased from 0.78 to 0.02

# %%
sns.distplot(df['Horizontal_Distance_To_Hydrology'])

# %%
sns.distplot(np.sqrt(df['Horizontal_Distance_To_Hydrology']))

# %%
sns.boxplot(np.sqrt(df['Horizontal_Distance_To_Hydrology']))

# %%
pd.Series(np.sqrt(df['Horizontal_Distance_To_Hydrology'])).skew()
# Out:
# 0.00673706487212228

# %%
df['Horizontal_Distance_To_Hydrology'].skew()
# Out:
# 1.140437391927878

# %% [markdown]
# After applying square root transformation to the column 'Horizontal_Distance_To_Hydrology', the skewness decreased from 1.14 to 0.006

# %%
sns.distplot(df['Vertical_Distance_To_Hydrology'])

# %%
sns.distplot(df['Vertical_Distance_To_Hydrology']**1/2)

# %%
df['Cover_Type'].value_counts()
# Out:
# 2    283301
# 1    211840
# 3     35754
# 7     20510
# 6     17367
# 5      9493
# 4      2747
# Name: Cover_Type, dtype: int64

# %%
sns.distplot(df['Horizontal_Distance_To_Roadways'])

# %%
sns.distplot(np.sqrt(df['Horizontal_Distance_To_Roadways']))

# %%
pd.Series(np.sqrt(df['Horizontal_Distance_To_Roadways'])).skew()
# Out:
# 0.09672119455964337

# %%
df['Horizontal_Distance_To_Roadways'].skew()
# Out:
# 0.7136788231003839

# %% [markdown]
# After doing square root transformation to the column 'Horizontal_Distance_To_Roadways', the skewness decreased from 0.71 to 0.09

# %%
cols = ['Hillshade_9am','Hillshade_Noon']
for col in cols:
  sns.distplot(np.power(df[col],2))
  print(pd.Series(np.power(df[col],10)).skew())
  plt.show()
# Out:
# -0.025256617966620796
# -0.08510709859746218

# %%
df['Hillshade_9am'].skew()
# Out:
# -1.18114666250383

# %%
cols = ['Hillshade_9am','Hillshade_Noon']
for col in cols:
  sns.distplot(df[col].apply(lambda x: np.log10(x+1)))
  print(df[col].apply(lambda x: np.log10(x+1)).skew())
  plt.show()
# Out:
# -2.956504485289512
# -3.0973151958830876

# %%
pd.Series()
# Out:
# Series([], dtype: float64)

# %%
df.columns
# Out:
# Index(['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
#        'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
#        'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
#        'Horizontal_Distance_To_Fire_Points', 'Wilderness_Area1',
#        'Wilderness_Area2', 'Wilderness_Area3', 'Wilderness_Area4',
#        'Soil_Type1', 'Soil_Type2', 'Soil_Type3', 'Soil_Type4', 'Soil_Type5',
#        'Soil_Type6', 'Soil_Type7', 'Soil_Type8', 'Soil_Type9', 'Soil_Type10',
#        'Soil_Type11', 'Soil_Type12', 'Soil_Type13', 'Soil_Type14',
#        'Soil_Type15', 'Soil_Type16', 'Soil_Type17', 'Soil_Type18',
#        'Soil_Type19', 'Soil_Type20', 'Soil_Type21', 'Soil_Type22',
#        'Soil_Type23', 'Soil_Type24', 'Soil_Type25', 'Soil_Type26',
#        'Soil_Type27', 'Soil_Type28', 'Soil_Type29', 'Soil_Type30',
#        'Soil_Type31', 'Soil_Type32', 'Soil_Type33', 'Soil_Type34',
#        'Soil_Type35', 'Soil_Type36', 'Soil_Type37', 'Soil_Type38',
# ...

# %%
import scipy.stats as st

# %%
print('Statistical test for Numerical features(ANOVA):')
for col in ['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
       'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
       'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
       'Horizontal_Distance_To_Fire_Points',]:
  grp1 = df[df['Cover_Type']==1][col]
  grp2 = df[df['Cover_Type']==2][col]
  grp3 = df[df['Cover_Type']==3][col]
  grp4 = df[df['Cover_Type']==4][col]
  grp5 = df[df['Cover_Type']==5][col]
  grp6 = df[df['Cover_Type']==6][col]
  grp7 = df[df['Cover_Type']==7][col]
  print('pvalue for ',col,' is:',st.f_oneway(grp1,grp2,grp3,grp4,grp5,grp6,grp7)[1])
# Out:
# Statistical test for Numerical features(ANOVA):
# pvalue for  Elevation  is: 0.0
# pvalue for  Aspect  is: 0.0
# pvalue for  Slope  is: 0.0
# pvalue for  Horizontal_Distance_To_Hydrology  is: 0.0
# pvalue for  Vertical_Distance_To_Hydrology  is: 0.0
# pvalue for  Horizontal_Distance_To_Roadways  is: 0.0
# pvalue for  Hillshade_9am  is: 0.0
# pvalue for  Hillshade_Noon  is: 0.0
# pvalue for  Hillshade_3pm  is: 0.0
# pvalue for  Horizontal_Distance_To_Fire_Points  is: 0.0

# %%
l1 = []
print('Statistical Test for Categorical Columns(CHI-SQUARE):')
for col in ['Wilderness_Area1',
       'Wilderness_Area2', 'Wilderness_Area3', 'Wilderness_Area4',
       'Soil_Type1', 'Soil_Type2', 'Soil_Type3', 'Soil_Type4', 'Soil_Type5',
       'Soil_Type6', 'Soil_Type7', 'Soil_Type8', 'Soil_Type9', 'Soil_Type10',
       'Soil_Type11', 'Soil_Type12', 'Soil_Type13', 'Soil_Type14',
       'Soil_Type15', 'Soil_Type16', 'Soil_Type17', 'Soil_Type18',
       'Soil_Type19', 'Soil_Type20', 'Soil_Type21', 'Soil_Type22',
       'Soil_Type23', 'Soil_Type24', 'Soil_Type25', 'Soil_Type26',
       'Soil_Type27', 'Soil_Type28', 'Soil_Type29', 'Soil_Type30',
       'Soil_Type31', 'Soil_Type32', 'Soil_Type33', 'Soil_Type34',
       'Soil_Type35', 'Soil_Type36', 'Soil_Type37', 'Soil_Type38',
       'Soil_Type39', 'Soil_Type40']:
  gpl = pd.crosstab(df[col],df['Cover_Type'])
  print('pvalue for ',col,' is:',st.chi2_contingency(gpl)[1])
# Out:
# Statistical Test for Categorical Columns(CHI-SQUARE):
# pvalue for  Wilderness_Area1  is: 0.0
# pvalue for  Wilderness_Area2  is: 0.0
# pvalue for  Wilderness_Area3  is: 0.0
# pvalue for  Wilderness_Area4  is: 0.0
# pvalue for  Soil_Type1  is: 0.0
# pvalue for  Soil_Type2  is: 0.0
# pvalue for  Soil_Type3  is: 0.0
# pvalue for  Soil_Type4  is: 0.0
# pvalue for  Soil_Type5  is: 0.0
# pvalue for  Soil_Type6  is: 0.0
# pvalue for  Soil_Type7  is: 1.7129654908603296e-21
# pvalue for  Soil_Type8  is: 2.4898563581535384e-11
# pvalue for  Soil_Type9  is: 3.892084170771216e-138
# pvalue for  Soil_Type10  is: 0.0
# pvalue for  Soil_Type11  is: 0.0
# pvalue for  Soil_Type12  is: 0.0
# pvalue for  Soil_Type13  is: 0.0
# pvalue for  Soil_Type14  is: 0.0
# pvalue for  Soil_Type15  is: 8.890831242782292e-19
# pvalue for  Soil_Type16  is: 2.397288685254257e-168
# pvalue for  Soil_Type17  is: 0.0
# pvalue for  Soil_Type18  is: 0.0
# pvalue for  Soil_Type19  is: 5.151252311605873e-282
# ...

# %%
df.corr()
# Out:
#                                     Elevation  ...  Cover_Type
# Elevation                            1.000000  ...   -0.269554
# Aspect                               0.015735  ...    0.017080
# Slope                               -0.242697  ...    0.148285
# Horizontal_Distance_To_Hydrology     0.306229  ...   -0.020317
# Vertical_Distance_To_Hydrology       0.093306  ...    0.081664
# Horizontal_Distance_To_Roadways      0.365559  ...   -0.153450
# Hillshade_9am                        0.112179  ...   -0.035415
# Hillshade_Noon                       0.205887  ...   -0.096426
# Hillshade_3pm                        0.059148  ...   -0.048290
# Horizontal_Distance_To_Fire_Points   0.148022  ...   -0.108936
# Wilderness_Area1                     0.131838  ...   -0.203913
# Wilderness_Area2                     0.238164  ...   -0.048059
# Wilderness_Area3                     0.066550  ...    0.066846
# Wilderness_Area4                    -0.619374  ...    0.323200
# ...

# %%
plt.figure(figsize=(30,5))
sns.heatmap(df.corr())

# %%
from sklearn.model_selection import train_test_split
X = df.drop('Cover_Type',axis=1)
y = df['Cover_Type']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=1)

# %%
cat_cols = ['Wilderness_Area1',
       'Wilderness_Area2', 'Wilderness_Area3', 'Wilderness_Area4',
       'Soil_Type1', 'Soil_Type2', 'Soil_Type3', 'Soil_Type4', 'Soil_Type5',
       'Soil_Type6', 'Soil_Type7', 'Soil_Type8', 'Soil_Type9', 'Soil_Type10',
       'Soil_Type11', 'Soil_Type12', 'Soil_Type13', 'Soil_Type14',
       'Soil_Type15', 'Soil_Type16', 'Soil_Type17', 'Soil_Type18',
       'Soil_Type19', 'Soil_Type20', 'Soil_Type21', 'Soil_Type22',
       'Soil_Type23', 'Soil_Type24', 'Soil_Type25', 'Soil_Type26',
       'Soil_Type27', 'Soil_Type28', 'Soil_Type29', 'Soil_Type30',
       'Soil_Type31', 'Soil_Type32', 'Soil_Type33', 'Soil_Type34',
       'Soil_Type35', 'Soil_Type36', 'Soil_Type37', 'Soil_Type38',
       'Soil_Type39', 'Soil_Type40']
X_train_cat = X_train[cat_cols]
X_test_cat = X_test[cat_cols]

# %%
num_cols = ['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
       'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
       'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
       'Horizontal_Distance_To_Fire_Points']
X_train_num = X_train[num_cols]
X_test_num = X_test[num_cols]
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_scaled_train_num = pd.DataFrame(ss.fit_transform(X_train_num),columns = X_train_num.columns)
X_scaled_test_num =  pd.DataFrame(ss.transform(X_test_num),columns = X_test_num.columns)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_scaled_train = pd.DataFrame(ss.fit_transform(X_train),columns = X_train.columns)
X_scaled_test=  pd.DataFrame(ss.transform(X_test),columns = X_test.columns)

# %%
X_scaled_train.head()
# Out:
#    Elevation    Aspect     Slope  ...  Soil_Type38  Soil_Type39  Soil_Type40
# 0  -0.673386 -1.114556  1.854403  ...    -0.165517    -0.156417    -0.123479
# 1   0.044748  0.538729  1.053627  ...    -0.165517    -0.156417    -0.123479
# 2  -0.066009 -0.506862 -0.414463  ...    -0.165517    -0.156417    -0.123479
# 3   1.027271 -0.185141 -1.081776  ...    -0.165517    -0.156417    -0.123479
# 4   1.563192  0.404679  2.521716  ...    -0.165517    -0.156417     8.098526
#
# [5 rows x 54 columns]

# %%
import statsmodels.api as sm
import warnings
warnings.filterwarnings('ignore')
glm = sm.GLM(y_train.ravel(),(sm.add_constant(X_scaled_train)))
model = glm.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:               406708
# Model:                            GLM   Df Residuals:                   406655
# Model Family:                Gaussian   Df Model:                           52
# Link Function:               identity   Scale:                          1.3260
# Method:                          IRLS   Log-Likelihood:            -6.3445e+05
# Date:                Fri, 14 Feb 2020   Deviance:                   5.3924e+05
# Time:                        14:25:19   Pearson chi2:                 5.39e+05
# No. Iterations:                     3
# Covariance Type:            nonrobust
# ...
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# ...

# %%
l1=[]
for i in range(model.pvalues.shape[0]):
    if model.pvalues[i]<=0.05 and model.pvalues.index[i]!='const':
        l1.append(model.pvalues.index[i])
print('Number of important features are ',len(l1))
# Out:
# Number of important features are  49

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
dt = DecisionTreeClassifier()
dtmodel = dt.fit(X_scaled_train,y_train)
lrmodel = lr.fit(X_scaled_train,y_train)

# %%
y_pred = dt.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.39      0.38      0.38     63547
#            2       0.44      0.00      0.00     84955
#            3       0.00      0.00      0.00     10771
#            4       0.00      0.00      0.00       808
#            5       0.00      0.00      0.00      2825
#            6       0.00      0.00      0.00      5239
#            7       0.04      0.81      0.08      6159
#
#     accuracy                           0.17    174304
#    macro avg       0.12      0.17      0.07    174304
# weighted avg       0.35      0.17      0.14    174304

# %% [markdown]
# **Applying Log Transformations**

# %%
def transform( df, before, after ):
    # Note: we do different transformations depending on the sign of the feature's skew
    print("%s => %s" % (before,after))
    fudge = 1
    skew_sign = df[before].skew()
    if (skew_sign > 0):
        if (df[before].min() < 0): fudge += -(df[before].min())
        df[after] = df[before].apply(lambda x: np.log10(x+fudge))
    else:
        fudge += df[before].max()
        df[after] = df[before].apply(lambda x: np.log10(fudge-x))
        
    print("   min before:",df[before].min())
    print("   max before:",df[before].max())
    print("   skew before:", df[before].skew())
    print("   skew_after:", df[after].skew())
    print("   min after:",df[after].min())
    print("   max after:",df[after].max())
    return df

def apply_transformations( new_data ):
    num_cols = ['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
       'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
       'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
       'Horizontal_Distance_To_Fire_Points']
    for col in num_cols:
      new_data = transform(new_data,col, col)
    return new_data

new_data = df

new_data = apply_transformations( new_data )

new_data.head(3)
# Out:
# Elevation => Elevation
#    min before: 0.0
#    max before: 3.3010299956639813
#    skew before: -0.6015243600129729
#    skew_after: -0.6015243600129729
#    min after: 0.0
#    max after: 3.3010299956639813
# Aspect => Aspect
#    min before: 0.0
#    max before: 2.5575072019056577
#    skew before: -1.3576498115415943
#    skew_after: -1.3576498115415943
#    min after: 0.0
#    max after: 2.5575072019056577
# Slope => Slope
#    min before: 0.0
#    max before: 1.8260748027008264
#    skew before: -0.6955712115430976
#    skew_after: -0.6955712115430976
#    min after: 0.0
#    max after: 1.8260748027008264
# Horizontal_Distance_To_Hydrology => Horizontal_Distance_To_Hydrology
#    min before: 0.0
#    max before: 3.1455071714096627
#    skew before: -2.1334426342589685
#    skew_after: -2.1334426342589685
#    min after: 0.0
#    max after: 3.1455071714096627
# Vertical_Distance_To_Hydrology => Vertical_Distance_To_Hydrology
#    min before: 0.0
# ...

# %%
from sklearn.model_selection import train_test_split
X = new_data.drop('Cover_Type',axis=1)
y = new_data['Cover_Type']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_scaled_train = pd.DataFrame(ss.fit_transform(X_train),columns = X_train.columns)
X_scaled_test=  pd.DataFrame(ss.transform(X_test),columns = X_test.columns)

# %%
from pandas import read_csv
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
from keras.utils import np_utils
dummy_y = np_utils.to_categorical(y_train)

# %%
model = Sequential()
model.add(Dense(32, input_shape=(54,), activation='relu'))
model.add(Dense(16,activation="relu"))
model.add(Dense(8,activation="softmax"))
model.compile(optimizer='adam',
     loss='categorical_crossentropy',
     metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "sequential_1"
# ...

# %%
model.fit(X_scaled_train, dummy_y,epochs=100,batch_size=500,validation_split=0.2)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 371847 samples, validate on 92962 samples
# Epoch 1/100
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
dt = DecisionTreeClassifier()
lr = LogisticRegression()
dtmodel = dt.fit(X_train,y_train)
lrmodel = lr.fit(X_train,y_train)

# %%
y_pred_dt = dtmodel.predict(X_test)
y_pred_lr = lrmodel.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_dt))
# Out:
# 0.9398982814557283

# %%
print(accuracy_score(y_test,y_pred_lr))
# Out:
# 0.6925896921766219

# %%
print(classification_report(y_test,y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.69      0.63      0.66     42212
#            2       0.71      0.80      0.76     56849
#            3       0.62      0.76      0.68      7094
#            4       0.60      0.48      0.53       569
#            5       0.40      0.04      0.08      1886
#            6       0.39      0.17      0.23      3502
#            7       0.64      0.46      0.54      4091
#
#     accuracy                           0.69    116203
#    macro avg       0.58      0.48      0.50    116203
# weighted avg       0.68      0.69      0.68    116203

# %%
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydot


# Putting features
features = list(X.columns)
features
# Out:
# ['Elevation',
#  'Aspect',
#  'Slope',
#  'Horizontal_Distance_To_Hydrology',
#  'Vertical_Distance_To_Hydrology',
#  'Horizontal_Distance_To_Roadways',
#  'Hillshade_9am',
#  'Hillshade_Noon',
#  'Hillshade_3pm',
#  'Horizontal_Distance_To_Fire_Points',
#  'Wilderness_Area1',
#  'Wilderness_Area2',
#  'Wilderness_Area3',
#  'Wilderness_Area4',
#  'Soil_Type1',
#  'Soil_Type2',
#  'Soil_Type3',
#  'Soil_Type4',
#  'Soil_Type5',
#  'Soil_Type6',
#  'Soil_Type7',
#  'Soil_Type8',
#  'Soil_Type9',
#  'Soil_Type10',
#  'Soil_Type11',
#  'Soil_Type12',
#  'Soil_Type13',
#  'Soil_Type14',
#  'Soil_Type15',
#  'Soil_Type16',
#  'Soil_Type17',
#  'Soil_Type18',
#  'Soil_Type19',
#  'Soil_Type20',
#  'Soil_Type21',
#  'Soil_Type22',
#  'Soil_Type23',
#  'Soil_Type24',
#  'Soil_Type25',
#  'Soil_Type26',
#  'Soil_Type27',
#  'Soil_Type28',
#  'Soil_Type29',
#  'Soil_Type30',
#  'Soil_Type31',
#  'Soil_Type32',
#  'Soil_Type33',
#  'Soil_Type34',
#  'Soil_Type35',
#  'Soil_Type36',
# ...

# %%
# plotting tree with max_depth=3
# dot_data = StringIO()  
# export_graphviz(dtmodel, out_file=dot_data,feature_names=features,filled=True,rounded=True)

# graph = pydot.graph_from_dot_data(dot_data.getvalue())
# Image(graph[0].create_png())

# %%
from sklearn.model_selection import KFold,cross_val_score
LR= LogisticRegression()
DT=DecisionTreeClassifier()
models = []
models.append(('Logistic Regression',LR))
models.append(('DT',DT))
results = []
names = []
for name, model in models:
   kfold = KFold(n_splits=10,shuffle=True,random_state=0)
   cv_results = cross_val_score(model,X,y,cv=kfold,scoring='f1_weighted')
   results.append(np.sqrt(np.abs(cv_results)))
   names.append(name)
   print("%s: %f (%f)" % (name, np.mean(cv_results),np.std(cv_results,ddof=1)))
#boxplot algorithm comparison
# Out:
# Logistic Regression: 0.679971 (0.003161)
# DT: 0.942371 (0.000906)

# %%
fig = plt.figure(figsize=(10,5))
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
